# %%
import pandas as pd

df = pd.read_csv("datasets/ETT-data/ETTh1_labeled.csv")

zeros = df.iloc[:, -1].eq(0).sum()
ones = df.iloc[:, -1].eq(1).sum()
total = len(df)
print(total)
print(ones)
red = (ones / total) * 100
print(red)
print((red * total) / 100)
# Out:
# 17400
# 93
# 0.5344827586206896
# 93.0
